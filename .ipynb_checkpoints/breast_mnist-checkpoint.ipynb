# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bmnst = np.load("breastmnist.npz")

# %%
print(bmnst)
# Out:
# <numpy.lib.npyio.NpzFile object at 0x152fadbd0>

# %%
bmnst.files
# Out:
# ['train_images',
#  'val_images',
#  'test_images',
#  'train_labels',
#  'val_labels',
#  'test_labels']

# %%
train_labels = bmnst['train_labels'].squeeze()
train_images = bmnst['train_images']

val_labels = bmnst['val_labels'].squeeze()
val_images = bmnst['val_images']

test_labels = bmnst['test_labels'].squeeze()
test_images = bmnst['test_images']

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (546, 28, 28)
# (546,)

# %%
print(val_images.shape)
print(val_labels.shape)
# Out:
# (78, 28, 28)
# (78,)

# %%
print(test_images.shape)
print(test_labels.shape)
# Out:
# (156, 28, 28)
# (156,)

# %%
plt.figure()
plt.imshow(train_images[50])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 546 samples
# Epoch 1/10
# 546/546 [==============================] - 0s 356us/sample - loss: 0.7382 - accuracy: 0.6941
# Epoch 2/10
# 546/546 [==============================] - 0s 35us/sample - loss: 0.5498 - accuracy: 0.7344
# Epoch 3/10
# 546/546 [==============================] - 0s 44us/sample - loss: 0.5280 - accuracy: 0.7509
# Epoch 4/10
# 546/546 [==============================] - 0s 44us/sample - loss: 0.4938 - accuracy: 0.7637
# Epoch 5/10
# 546/546 [==============================] - 0s 47us/sample - loss: 0.4829 - accuracy: 0.7766
# Epoch 6/10
# 546/546 [==============================] - 0s 50us/sample - loss: 0.5112 - accuracy: 0.7582
# Epoch 7/10
# 546/546 [==============================] - 0s 51us/sample - loss: 0.4731 - accuracy: 0.8077
# Epoch 8/10
# 546/546 [==============================] - 0s 45us/sample - loss: 0.4942 - accuracy: 0.7729
# Epoch 9/10
# 546/546 [==============================] - 0s 42us/sample - loss: 0.4614 - accuracy: 0.8077
# Epoch 10/10
# 546/546 [==============================] - 0s 38us/sample - loss: 0.4796 - accuracy: 0.7949

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 156/156 - 0s - loss: 0.4650 - accuracy: 0.7949
#
# Test accuracy: 0.7948718

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([7.2518390e-01, 2.7386209e-01, 6.6158711e-05, 7.2579824e-05,
#        1.0005142e-04, 1.0733858e-04, 2.0252384e-04, 2.1241448e-04,
#        1.6166871e-04, 3.1304971e-05], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 0

# %%
test_labels[0]
# Out:
# 0

# %%
#Changing the number of neurons

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 546 samples
# Epoch 1/10
# 546/546 [==============================] - 0s 355us/sample - loss: 0.7709 - accuracy: 0.6264
# Epoch 2/10
# 546/546 [==============================] - 0s 40us/sample - loss: 0.5110 - accuracy: 0.7418
# Epoch 3/10
# 546/546 [==============================] - 0s 46us/sample - loss: 0.5137 - accuracy: 0.7656
# Epoch 4/10
# 546/546 [==============================] - 0s 53us/sample - loss: 0.5123 - accuracy: 0.7473
# Epoch 5/10
# 546/546 [==============================] - 0s 56us/sample - loss: 0.5198 - accuracy: 0.7509
# Epoch 6/10
# 546/546 [==============================] - 0s 53us/sample - loss: 0.4708 - accuracy: 0.7894
# Epoch 7/10
# 546/546 [==============================] - 0s 49us/sample - loss: 0.4566 - accuracy: 0.8077
# Epoch 8/10
# 546/546 [==============================] - 0s 44us/sample - loss: 0.4573 - accuracy: 0.7967
# Epoch 9/10
# 546/546 [==============================] - 0s 52us/sample - loss: 0.4625 - accuracy: 0.8040
# Epoch 10/10
# 546/546 [==============================] - 0s 54us/sample - loss: 0.4389 - accuracy: 0.8114

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 156/156 - 0s - loss: 0.4542 - accuracy: 0.7949
#
# Test accuracy: 0.7948718

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([6.6401041e-01, 3.3496001e-01, 5.7283152e-05, 1.8367829e-04,
#        1.6302586e-04, 1.8142207e-04, 1.4852268e-04, 4.2497184e-05,
#        1.8621227e-04, 6.6951892e-05], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 0

# %%
test_labels[0]
# Out:
# 0

# %%
#adding layer - 2 and 3 

two_layer_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(4)
])

# %%
two_layer_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
two_layer_model.fit(train_images, train_labels, epochs=4)
# Out:
# Train on 546 samples
# Epoch 1/4
# 546/546 [==============================] - 0s 391us/sample - loss: 0.7064 - accuracy: 0.6905
# Epoch 2/4
# 546/546 [==============================] - 0s 43us/sample - loss: 0.5663 - accuracy: 0.7418
# Epoch 3/4
# 546/546 [==============================] - 0s 41us/sample - loss: 0.5089 - accuracy: 0.7656
# Epoch 4/4
# 546/546 [==============================] - 0s 44us/sample - loss: 0.4841 - accuracy: 0.7692

# %%
val_loss, val_acc = two_layer_model.evaluate(val_images, val_labels, verbose=2)
# Out:
# 78/78 - 0s - loss: 37.2827 - accuracy: 0.7821

# %%
probability_model = tf.keras.Sequential([two_layer_model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([0.72302735, 0.27236882, 0.00216271, 0.00244113], dtype=float32)

# %%
np.argmax(predictions[0])

test_labels[0]
# Out:
# 0

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(4))
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()

# %%
three_layer_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(4)
])

# %%
three_layer_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
three_layer_model.fit(train_images, train_labels, epochs=4)
# Out:
# Train on 546 samples
# Epoch 1/4
# 546/546 [==============================] - 0s 423us/sample - loss: 0.8173 - accuracy: 0.6996
# Epoch 2/4
# 546/546 [==============================] - 0s 44us/sample - loss: 0.6066 - accuracy: 0.7308
# Epoch 3/4
# 546/546 [==============================] - 0s 48us/sample - loss: 0.5716 - accuracy: 0.7308
# Epoch 4/4
# 546/546 [==============================] - 0s 43us/sample - loss: 0.5420 - accuracy: 0.7308

# %%
val_loss, val_acc = three_layer_model.evaluate(val_images, val_labels, verbose=2)
# Out:
# 78/78 - 0s - loss: 46.9348 - accuracy: 0.7308

# %%
probability_model = tf.keras.Sequential([two_layer_model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
# Out:
# array([0.72302735, 0.27236882, 0.00216271, 0.00244113], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 0

# %%
test_labels[0]
# Out:
# 0

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(4))
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
